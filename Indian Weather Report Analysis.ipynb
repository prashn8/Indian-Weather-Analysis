# %% [markdown]
# INDIAN WEATHER REPORT ANALYSIS

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Checking the values of the data
df = pd.read_csv('IndianWeatherReport.csv')
df.head()
# Out:
#   country location_name          region  latitude  longitude      timezone  \
# 0   India    Ashoknagar  Madhya Pradesh     24.57      77.72  Asia/Kolkata
# 1   India        Raisen  Madhya Pradesh     23.33      77.80  Asia/Kolkata
# 2   India    Chhindwara  Madhya Pradesh     22.07      78.93  Asia/Kolkata
# 3   India         Betul  Madhya Pradesh     21.86      77.93  Asia/Kolkata
# 4   India   Hoshangabad  Madhya Pradesh     22.75      77.72  Asia/Kolkata
#
#    last_updated_epoch      last_updated  temperature_celsius  \
# 0          1693286100  2023-08-29 10:45                 27.5
# 1          1693286100  2023-08-29 10:45                 27.5
# 2          1693286100  2023-08-29 10:45                 26.3
# 3          1693286100  2023-08-29 10:45                 25.6
# 4          1693286100  2023-08-29 10:45                 27.2
#
#    temperature_fahrenheit  ... air_quality_PM2.5  air_quality_PM10  \
# 0                    81.5  ...              12.6              18.5
# ...

# %%
#Checking the shape of the data
df.shape
# Out:
# (24070, 42)

# %%
#Checking the info and if there is any null value in the data
df.info()
pd.isnull(df).sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24070 entries, 0 to 24069
# Data columns (total 42 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       24070 non-null  object
#  1   location_name                 24070 non-null  object
#  2   region                        24070 non-null  object
#  3   latitude                      24070 non-null  float64
#  4   longitude                     24070 non-null  float64
#  5   timezone                      24070 non-null  object
#  6   last_updated_epoch            24070 non-null  int64
#  7   last_updated                  24070 non-null  object
#  8   temperature_celsius           24070 non-null  float64
#  9   temperature_fahrenheit        24070 non-null  float64
#  10  condition_text                24070 non-null  object
#  11  wind_mph                      24070 non-null  float64
# ...

# %%
#Filter the data by the location name of the city
filtered_df = df[df['location_name'] == 'Rewa']
filtered_df
# Out:
#       country location_name          region  latitude  longitude  \
# 10      India          Rewa  Madhya Pradesh     24.53       81.3
# 553     India          Rewa  Madhya Pradesh     24.53       81.3
# 1103    India          Rewa  Madhya Pradesh     24.53       81.3
# 1653    India          Rewa  Madhya Pradesh     24.53       81.3
# 2197    India          Rewa  Madhya Pradesh     24.53       81.3
# 2746    India          Rewa  Madhya Pradesh     24.53       81.3
# 3290    India          Rewa  Madhya Pradesh     24.53       81.3
# 3834    India          Rewa  Madhya Pradesh     24.53       81.3
# 4383    India          Rewa  Madhya Pradesh     24.53       81.3
# 4928    India          Rewa  Madhya Pradesh     24.53       81.3
# 5473    India          Rewa  Madhya Pradesh     24.53       81.3
# 6022    India          Rewa  Madhya Pradesh     24.53       81.3
# 6572    India          Rewa  Madhya Pradesh     24.53       81.3
# ...

# %%
#Calculating the average temperature in Celsius for Rewa
avg_temp_rewa = df['temperature_celsius'].mean()

# Calculating the maximum temperature in Celsius for Rewa
max_temp_rewa = df['temperature_celsius'].max()

# Calculating the minimum temperature in Celsius for Rewa
min_temp_rewa = df['temperature_celsius'].min()

print(f"The average temperature in Celsius for Rewa is {avg_temp_rewa:.2f}°C")
print(f"The maximum temperature in Celsius for Rewa is {max_temp_rewa:.2f}°C")
print(f"The minimum temperature in Celsius for Rewa is {min_temp_rewa:.2f}°C")
# Out:
# The average temperature in Celsius for Rewa is 24.32°C
# The maximum temperature in Celsius for Rewa is 38.30°C
# The minimum temperature in Celsius for Rewa is -5.30°C

# %%
# Group by 'region' and calculate mean temperature
region_mean_temp = df.groupby('region')['temperature_celsius'].mean()
region_mean_temp
# Out:
# region
# Andaman and Nicobar Islands    27.386364
# Andhra Pradesh                 24.879402
# Arunachal Pradesh              15.064773
# Assam                          25.004320
# Bihar                          26.857994
# Chandigarh                     23.663636
# Chhattisgarh                   23.424704
# Dadra and Nagar Haveli         25.413636
# Daman and Diu                  25.775000
# Delhi                          27.096591
# Goa                            25.725843
# Gujarat                        26.029644
# Haryana                        26.472386
# Himachal Pradesh               16.603182
# Jammu and Kashmir              15.036177
# Jharkhand                      25.021465
# Karnataka                      22.325762
# Kerala                         24.513149
# Lakshadweep                    27.447727
# Madhya Pradesh                 23.629431
# Maharashtra                    23.787190
# Manipur                        19.240510
# Mizoram                        21.297078
# ...

# %%
# Group by 'location_name' and calculate mean air quality
location_mean_air_quality = df.groupby('location_name')[['air_quality_PM2.5', 'air_quality_PM10']].mean()
location_mean_air_quality
# Out:
#                air_quality_PM2.5  air_quality_PM10
# location_name
# Adilabad               30.811364         37.275000
# Agar                   38.306818         50.043182
# Agra                   89.665909        112.747727
# Ahmadnagar             23.420455         30.188636
# Aizawl                 10.288636         11.090909
# ...                          ...               ...
# Yadgir                 17.915909         24.188636
# Yamunanagar           129.834091        152.645455
# Yanam                  54.875000         62.831818
# Yavatmal               35.422727         42.940909
# Zunheboto               8.304545          9.927273
#
# [543 rows x 2 columns]

# %%
# Get the top 10 locations with the highest average air quality PM2.5
top_10_worst_air_quality = df.groupby('location_name')['air_quality_PM2.5'].mean().nlargest(10)

# Print the list of top 10 locations with the worst air quality
print("Top 10 Locations with Worst Air Quality (PM2.5):")
top_10_worst_air_quality
# Out:
# Top 10 Locations with Worst Air Quality (PM2.5):
# location_name
# Faridabad     230.070455
# Shahdara      207.227273
# Jalandhar     178.790909
# Ghaziabad     178.436364
# Kapurthala    178.334091
# Gurgaon       177.840909
# Niwari        177.734091
# Ludhiana      175.488636
# New Delhi     174.970455
# Tarn Taran    172.947727
# Name: air_quality_PM2.5, dtype: float64

# %%
# Top five hottest locations and temperatures
top_hottest = df.nlargest(5, 'temperature_celsius')[['location_name', 'temperature_celsius']]
print("Top five hottest locations and temperatures:")
top_hottest
# Out:
# Top five hottest locations and temperatures:
#      location_name  temperature_celsius
# 9145       Bikaner                 38.3
# 9063       Fazilka                 36.3
# 9142    Ganganagar                 36.3
# 9139   Hanumangarh                 35.6
# 107        Nellore                 35.3

# %%
# Top five coldest locations and temperatures
top_coldest = df.nsmallest(5, 'temperature_celsius')[['location_name', 'temperature_celsius']]
print("\nTop five coldest locations and temperatures:")
top_coldest
# Out:
# Top five coldest locations and temperatures:
#       location_name  temperature_celsius
# 22690    Uttarkashi                 -5.3
# 19414    Uttarkashi                 -4.5
# 19961    Uttarkashi                 -4.5
# 20510    Uttarkashi                 -4.5
# 17229    Uttarkashi                 -4.4

# %%
# Line plot of temperature over time for 'Rewa'
rewa_df = df[df['location_name'] == 'Rewa']
rewa_df['temperature_celsius'].plot(kind='line', title='Temperature Over Time for Rewa')
plt.show()

# %%
# Box plot of air quality across different locations
sns.boxplot(x='region', y='air_quality_PM2.5', data=df)
plt.title('Air Quality PM2.5 Across Regions')
plt.show()

# %%
sns.boxplot(x='region', y='temperature_celsius', data=df)
plt.title('Box Plot of Temperature by region')
plt.xlabel('Location')
plt.ylabel('Temperature (Celsius)')
plt.xticks(rotation=90)
plt.show()

# %%
# Violin plot of air quality PM2.5 across different locations
plt.figure(figsize=(20, 5))
sns.violinplot(x='region', y='air_quality_PM2.5', data=df)
plt.title('Air Quality PM2.5 Across Locations')
plt.xlabel('Location')
plt.ylabel('PM2.5')
plt.xticks(rotation=45)
plt.show()

# %%
# Violin plot of air quality PM2.5 across different locations
plt.figure(figsize=(20, 5))
sns.violinplot(x='region', y='temperature_celsius', data=df)
plt.title('Temprature In Celsius Across Locations')
plt.xlabel('Location')
plt.ylabel('Temprature')
plt.xticks(rotation=45)
plt.show()

# %%
# Get top 10 hottest and coldest locations with temperatures
top_10_hottest = df.nlargest(10, 'temperature_celsius')[['location_name', 'temperature_celsius']]
top_10_coldest = df.nsmallest(10, 'temperature_celsius')[['location_name', 'temperature_celsius']]

# Create a pie chart for the top 10 hottest locations and temperatures
plt.figure(figsize=(10, 5))
plt.pie(top_10_hottest['temperature_celsius'], labels=top_10_hottest['location_name'], autopct='%1.1f%%', startangle=140, colors=sns.color_palette("pastel"))
plt.title('Top 10 Hottest Locations and Temperatures')
plt.show()
